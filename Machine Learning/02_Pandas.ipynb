# %%
import pandas as pd
import numpy as np
import matplotlib as mlt

# %% [markdown]
# ### Pandas Data Types
# 1. Series type
# 2. Data Frames

# %%
# Series data type = One Dimentional (single column)

carData = pd.Series(["Corolla", "BMW", "Suzuki", "Audi"])
carData
# Out:
# 0    Corolla
# 1        BMW
# 2     Suzuki
# 3       Audi
# dtype: object

# %%
carColor=pd.Series(["White", "Red", "Black", "Black"])
carColor
# Out:
# 0    White
# 1      Red
# 2    Black
# 3    Black
# dtype: object

# %%
carDataFrame=pd.DataFrame({"Car": carData, "Color":carColor})
carDataFrame
# Out:
#        Car  Color
# 0  Corolla  White
# 1      BMW    Red
# 2   Suzuki  Black
# 3     Audi  Black

# %% [markdown]
# ### Importing and Exporting Data as DataFrames
# 1. read_csv function
# 2. to_cvs function

# %%
carDataFrame=pd.read_csv("car-sales.csv")
carDataFrame
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
carDataFrame.to_csv("carNewData.csv", index=False)

# %%
newcarDataFrame=pd.read_csv("carNewData.csv")

# %%
newcarDataFrame
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# ## Describing data using Pandas

# %%
newcarDataFrame.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
newcarDataFrame.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
newcarDataFrame.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
newcarDataFrame["Doors"].mean()
# Out:
# np.float64(4.0)

# %%
newcarDataFrame.sum()
# Out:
# Make             ToyotaHondaToyotaBMWNissanToyotaHondaHondaToyo...
# Colour               WhiteRedBlueBlackWhiteGreenBlueBlueWhiteWhite
# Odometer (KM)                                               786014
# Doors                                                           40
# Price            $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00...
# dtype: object

# %%
newcarDataFrame["Odometer (KM)"].sum()
# Out:
# np.int64(786014)

# %%
len(newcarDataFrame)
# Out:
# 10

# %%
newcarDataFrame.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
newcarDataFrame.tail()
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %% [markdown]
# ## Viewing and Selecting Data

# %%
newcarDataFrame.head(6)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00

# %%
newcarDataFrame.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
newcarDataFrame.iloc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
sampleSeries=pd.Series(["peshawar", "karachi", "islamabad", "lahore", "kohat", "abbotabad"], index=[1,3,4,7,6,9])

# %%
sampleSeries
# Out:
# 1     peshawar
# 3      karachi
# 4    islamabad
# 7       lahore
# 6        kohat
# 9    abbotabad
# dtype: object

# %%
sampleSeries.loc[3]
# Out:
# 'karachi'

# %%
sampleSeries.iloc[3]
# Out:
# 'lahore'

# %%
# Basic Slicing using loc

newcarDataFrame.loc[:4]
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
newcarDataFrame.Make # newcarDataFrame["Odometer (KM)"]
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
newcarDataFrame[newcarDataFrame["Odometer (KM)"]> 150000]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 4  Nissan  White         213095      4  $3,500.00

# %%
# Comparing different columns
pd.crosstab(newcarDataFrame["Make"], newcarDataFrame["Doors"])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
pd.crosstab(newcarDataFrame["Make"], newcarDataFrame["Price"])
# Out:
# Price   $22,000.00  $3,500.00  $4,000.00  $4,500.00  $5,000.00  $6,250.00  \
# Make
# BMW              1          0          0          0          0          0
# Honda            0          0          0          0          1          0
# Nissan           0          1          0          0          0          0
# Toyota           0          0          1          1          0          1
#
# Price   $7,000.00  $7,500.00  $9,700.00
# Make
# BMW             0          0          0
# Honda           1          1          0
# Nissan          0          0          1
# Toyota          1          0          0

# %%
newcarDataFrame.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
newcarDataFrame.groupby(["Make"]).mean(numeric_only=True)
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
newcarDataFrame["Odometer (KM)"].plot()
# Out:
# <Axes: >

# %%
newcarDataFrame
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# looking at data spread
newcarDataFrame["Odometer (KM)"].hist()
# Out:
# <Axes: >

# %%
newcarDataFrame["Price"].hist()
# Out:
# <Axes: >

# %% [markdown]
# ## Data Manupilation

# %%
newcarDataFrame["Make"]=newcarDataFrame["Make"].str.upper()

# %%
newcarDataFrame
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  TOYOTA  White         150043      4   $4,000.00
# 1   HONDA    Red          87899      4   $5,000.00
# 2  TOYOTA   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  NISSAN  White         213095      4   $3,500.00
# 5  TOYOTA  Green          99213      4   $4,500.00
# 6   HONDA   Blue          45698      4   $7,500.00
# 7   HONDA   Blue          54738      4   $7,000.00
# 8  TOYOTA  White          60000      4   $6,250.00
# 9  NISSAN  White          31600      4   $9,700.00

# %%
newcarDataFrame["Make"]=newcarDataFrame["Make"].str.lower()

# %%
newcarDataFrame
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  toyota  White         150043      4   $4,000.00
# 1   honda    Red          87899      4   $5,000.00
# 2  toyota   Blue          32549      3   $7,000.00
# 3     bmw  Black          11179      5  $22,000.00
# 4  nissan  White         213095      4   $3,500.00
# 5  toyota  Green          99213      4   $4,500.00
# 6   honda   Blue          45698      4   $7,500.00
# 7   honda   Blue          54738      4   $7,000.00
# 8  toyota  White          60000      4   $6,250.00
# 9  nissan  White          31600      4   $9,700.00

# %%
missingDataFrame = pd.read_csv("carMissingData.csv")
missingDataFrame
# Out:
#      Make Colour  Odometer (KM)  Doors        Price
# 0  Toyota  White       150043.0      4   $4,000.00
# 1   Honda    NaN        87899.0      4   $5,000.00
# 2  Toyota   Blue            NaN      3   $7,000.00
# 3     BMW  Black        11179.0      5  $22,000.00
# 4  Nissan  White       213095.0      4   $3,500.00
# 5  Toyota  Green        99213.0      4   $4,500.00
# 6   Honda    NaN            NaN      4   $7,500.00
# 7   Honda   Blue        54738.0      4          NaN
# 8  Toyota  White        60000.0      4   $6,250.00
# 9  Nissan  White        31600.0      4   $9,700.00

# %%
#missingDataFrame["Odometer (KM)"] = missingDataFrame["Odometer (KM)"].fillna(missingDataFrame["Odometer (KM)"].mean())
#missingDataFrame
missingDataFrame["Odometer (KM)"].fillna(missingDataFrame["Odometer (KM)"].mean(), inplace=True)
# Out:
# C:\Users\Adeel\AppData\Local\Temp\ipykernel_6924\237639714.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   missingDataFrame["Odometer (KM)"].fillna(missingDataFrame["Odometer (KM)"].mean(), inplace=True)

# %%
missingDataFrame
# Out:
#      Make Colour  Odometer (KM)  Doors        Price
# 0  Toyota  White     150043.000      4   $4,000.00
# 1   Honda    NaN      87899.000      4   $5,000.00
# 2  Toyota   Blue      88470.875      3   $7,000.00
# 3     BMW  Black      11179.000      5  $22,000.00
# 4  Nissan  White     213095.000      4   $3,500.00
# 5  Toyota  Green      99213.000      4   $4,500.00
# 6   Honda    NaN      88470.875      4   $7,500.00
# 7   Honda   Blue      54738.000      4          NaN
# 8  Toyota  White      60000.000      4   $6,250.00
# 9  Nissan  White      31600.000      4   $9,700.00

# %%
missingDataFrame.dropna()
# Out:
#      Make Colour  Odometer (KM)  Doors        Price
# 0  Toyota  White     150043.000      4   $4,000.00
# 2  Toyota   Blue      88470.875      3   $7,000.00
# 3     BMW  Black      11179.000      5  $22,000.00
# 4  Nissan  White     213095.000      4   $3,500.00
# 5  Toyota  Green      99213.000      4   $4,500.00
# 8  Toyota  White      60000.000      4   $6,250.00
# 9  Nissan  White      31600.000      4   $9,700.00

# %%
missingDataFrame
# Out:
#      Make Colour  Odometer (KM)  Doors        Price
# 0  Toyota  White     150043.000      4   $4,000.00
# 1   Honda    NaN      87899.000      4   $5,000.00
# 2  Toyota   Blue      88470.875      3   $7,000.00
# 3     BMW  Black      11179.000      5  $22,000.00
# 4  Nissan  White     213095.000      4   $3,500.00
# 5  Toyota  Green      99213.000      4   $4,500.00
# 6   Honda    NaN      88470.875      4   $7,500.00
# 7   Honda   Blue      54738.000      4          NaN
# 8  Toyota  White      60000.000      4   $6,250.00
# 9  Nissan  White      31600.000      4   $9,700.00

# %%
missingDataFrame.dropna(inplace=True)

# %%
missingDataFrame
# Out:
#      Make Colour  Odometer (KM)  Doors        Price
# 0  Toyota  White     150043.000      4   $4,000.00
# 2  Toyota   Blue      88470.875      3   $7,000.00
# 3     BMW  Black      11179.000      5  $22,000.00
# 4  Nissan  White     213095.000      4   $3,500.00
# 5  Toyota  Green      99213.000      4   $4,500.00
# 8  Toyota  White      60000.000      4   $6,250.00
# 9  Nissan  White      31600.000      4   $9,700.00

# %%
# Adding columns to dataframe
#1. from series data.

manufacturingYear = pd.Series([1999, 2000, 2012, 2022, 2011])
missingDataFrame["Manufacturing Year"] = manufacturingYear

# %%
missingDataFrame
# Out:
#      Make Colour  Odometer (KM)  Doors        Price  Manufacturing Year
# 0  Toyota  White     150043.000      4   $4,000.00               1999.0
# 2  Toyota   Blue      88470.875      3   $7,000.00               2012.0
# 3     BMW  Black      11179.000      5  $22,000.00               2022.0
# 4  Nissan  White     213095.000      4   $3,500.00               2011.0
# 5  Toyota  Green      99213.000      4   $4,500.00                  NaN
# 8  Toyota  White      60000.000      4   $6,250.00                  NaN
# 9  Nissan  White      31600.000      4   $9,700.00                  NaN

# %%
missingDataFrame.fillna(1996, inplace=True)

# %%
missingDataFrame
# Out:
#      Make Colour  Odometer (KM)  Doors        Price  Manufacturing Year
# 0  Toyota  White     150043.000      4   $4,000.00               1999.0
# 2  Toyota   Blue      88470.875      3   $7,000.00               2012.0
# 3     BMW  Black      11179.000      5  $22,000.00               2022.0
# 4  Nissan  White     213095.000      4   $3,500.00               2011.0
# 5  Toyota  Green      99213.000      4   $4,500.00               1996.0
# 8  Toyota  White      60000.000      4   $6,250.00               1996.0
# 9  Nissan  White      31600.000      4   $9,700.00               1996.0

# %%
fuel_economy=pd.Series([10, 9, 12.5, 11])
missingDataFrame["Fuel_Eco"] = fuel_economy

# %%
missingDataFrame
# Out:
#      Make Colour  Odometer (KM)  Doors        Price  Manufacturing Year  \
# 0  Toyota  White     150043.000      4   $4,000.00               1999.0
# 2  Toyota   Blue      88470.875      3   $7,000.00               2012.0
# 3     BMW  Black      11179.000      5  $22,000.00               2022.0
# 4  Nissan  White     213095.000      4   $3,500.00               2011.0
# 5  Toyota  Green      99213.000      4   $4,500.00               1996.0
# 8  Toyota  White      60000.000      4   $6,250.00               1996.0
# 9  Nissan  White      31600.000      4   $9,700.00               1996.0
#
#    Fuel_Eco
# 0      10.0
# 2      12.5
# 3      11.0
# 4       NaN
# 5       NaN
# 8       NaN
# 9       NaN

# %%
missingDataFrame["Fuel_Eco"].fillna(9.5, inplace=True)
# Out:
# C:\Users\Adeel\AppData\Local\Temp\ipykernel_6924\1966200817.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   missingDataFrame["Fuel_Eco"].fillna(9.5, inplace=True)

# %%
missingDataFrame
# Out:
#      Make Colour  Odometer (KM)  Doors        Price  Manufacturing Year  \
# 0  Toyota  White     150043.000      4   $4,000.00               1999.0
# 2  Toyota   Blue      88470.875      3   $7,000.00               2012.0
# 3     BMW  Black      11179.000      5  $22,000.00               2022.0
# 4  Nissan  White     213095.000      4   $3,500.00               2011.0
# 5  Toyota  Green      99213.000      4   $4,500.00               1996.0
# 8  Toyota  White      60000.000      4   $6,250.00               1996.0
# 9  Nissan  White      31600.000      4   $9,700.00               1996.0
#
#    Fuel_Eco
# 0      10.0
# 2      12.5
# 3      11.0
# 4       9.5
# 5       9.5
# 8       9.5
# 9       9.5

# %%
missingDataFrame["Fuel_consumed"]=missingDataFrame["Odometer (KM)"]/missingDataFrame["Fuel_Eco"]
missingDataFrame
# Out:
#      Make Colour  Odometer (KM)  Doors        Price  Manufacturing Year  \
# 0  Toyota  White     150043.000      4   $4,000.00               1999.0
# 2  Toyota   Blue      88470.875      3   $7,000.00               2012.0
# 3     BMW  Black      11179.000      5  $22,000.00               2022.0
# 4  Nissan  White     213095.000      4   $3,500.00               2011.0
# 5  Toyota  Green      99213.000      4   $4,500.00               1996.0
# 8  Toyota  White      60000.000      4   $6,250.00               1996.0
# 9  Nissan  White      31600.000      4   $9,700.00               1996.0
#
#    Fuel_Eco  Fuel_consumed
# 0      10.0   15004.300000
# 2      12.5    7077.670000
# 3      11.0    1016.272727
# 4       9.5   22431.052632
# 5       9.5   10443.473684
# 8       9.5    6315.789474
# 9       9.5    3326.315789

# %%
missingDataFrame["Wheels"] = 4

# %%
missingDataFrame
# Out:
#      Make Colour  Odometer (KM)  Doors        Price  Manufacturing Year  \
# 0  Toyota  White     150043.000      4   $4,000.00               1999.0
# 2  Toyota   Blue      88470.875      3   $7,000.00               2012.0
# 3     BMW  Black      11179.000      5  $22,000.00               2022.0
# 4  Nissan  White     213095.000      4   $3,500.00               2011.0
# 5  Toyota  Green      99213.000      4   $4,500.00               1996.0
# 8  Toyota  White      60000.000      4   $6,250.00               1996.0
# 9  Nissan  White      31600.000      4   $9,700.00               1996.0
#
#    Fuel_Eco  Fuel_consumed  Wheels
# 0      10.0   15004.300000       4
# 2      12.5    7077.670000       4
# 3      11.0    1016.272727       4
# 4       9.5   22431.052632       4
# 5       9.5   10443.473684       4
# 8       9.5    6315.789474       4
# 9       9.5    3326.315789       4

# %%
missingDataFrame.drop("Wheels", axis=1, inplace=True)

# %%
missingDataFrame
# Out:
#      Make Colour  Odometer (KM)  Doors        Price  Manufacturing Year  \
# 0  Toyota  White     150043.000      4   $4,000.00               1999.0
# 2  Toyota   Blue      88470.875      3   $7,000.00               2012.0
# 3     BMW  Black      11179.000      5  $22,000.00               2022.0
# 4  Nissan  White     213095.000      4   $3,500.00               2011.0
# 5  Toyota  Green      99213.000      4   $4,500.00               1996.0
# 8  Toyota  White      60000.000      4   $6,250.00               1996.0
# 9  Nissan  White      31600.000      4   $9,700.00               1996.0
#
#    Fuel_Eco  Fuel_consumed
# 0      10.0   15004.300000
# 2      12.5    7077.670000
# 3      11.0    1016.272727
# 4       9.5   22431.052632
# 5       9.5   10443.473684
# 8       9.5    6315.789474
# 9       9.5    3326.315789

# %%
heartDisease = pd.read_csv("heart-disease.csv")

# %%
heartDisease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
shuffledHeartData=heartDisease.sample(frac=1)

# %%
heartDisease
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...
